# %% [markdown]
# #RDF-to-Text: Fine-tuning GPT2 with WebNLG Corpus
# ###Fina Emilova Yilmaz Polat
#
# This is the third notebook of a series of 4.
#
# We are going to:
# * pre-process WebNLG Dataset - Part 1
# * fine-tune GPT2 language model with WebNLG Dataset. - Part 2
# * generate text with the trained model - Part 3
# * evaluate generated text - Part 4
#
# The WebNLG data (Gardent el al., 2017) was created to promote the development (i) of RDF verbalisers and (ii) of microplanners able to handle a wide range of linguistic constructions.
#
# Gardent, C., Shimorina, A., Narayan, S., & Perez-Beltrachini, L. (2017, September). The WebNLG challenge: Generating text from RDF data. In Proceedings of the 10th International Conference on Natural Language Generation (pp. 124-133).
#
# GPT2 Language Model : Radford, A., Wu, J., Child, R., Luan, D., Amodei, D., & Sutskever, I. (2019). Language models are unsupervised multitask learners. OpenAI blog, 1(8), 9.

# %%
#install required libraries
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 5.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 39.9 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 42.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.4 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 34.5 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.18.0

# %%
#import required libraries
from google.colab import drive
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import os
import glob
import re
import xml.etree.ElementTree as ET
import csv
from csv import reader

# %%
MOUNTPOINT = '/content/gdrive'
Working_Dir = os.path.join(MOUNTPOINT, 'My Drive', 'WebNLG with GPT2')
drive.mount(MOUNTPOINT)
print(Working_Dir)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/WebNLG with GPT2

# %% [markdown]
# We start with some pre-processing:
# 1. parse the test xml file with reference text.
# 2. filter the instances with 1 triple (for this study, we will evaluate only 1 triple instances.)
# 3. save it in a csv file
# 4. remove unwanted characters from the input text.
# 5. clean up the generated text for the evaluation.

# %%
#Parse the test file

file = "/content/gdrive/My Drive/WebNLG with GPT2/data/test/rdf-to-text-generation-test-data-with-refs-en.xml"
triple_re=re.compile('(\d)triples')
data_dct={}
tree = ET.parse(file)
root = tree.getroot()
for sub_root in root:
    for ss_root in sub_root:
        strutured_master=[]
        unstructured=[]
        for entry in ss_root:
            unstructured.append(entry.text)
            strutured=[triple.text for triple in entry]
            strutured_master.extend(strutured)
        unstructured=[i for i in unstructured if i.replace('\n','').strip()!='' ]
        strutured_master_str=(' && ').join(strutured_master)
        data_dct[strutured_master_str]=unstructured
mdata_dct={"prefix":[], "input_text":[], "target_text":[]}
for st,unst in data_dct.items():
    for i in unst:
        mdata_dct['prefix'].append('webNLG')
        mdata_dct['input_text'].append(st)
        mdata_dct['target_text'].append(i)


df=pd.DataFrame(mdata_dct)
df.to_csv('/content/gdrive/My Drive/WebNLG with GPT2/data/webNLG2020_test.csv')

# %%
#Lets check the file:
test_df=pd.read_csv('/content/gdrive/My Drive/WebNLG with GPT2/data/webNLG2020_test.csv', index_col=[0])
#Let's inspect the dataset:
test_df.head
# Out:
# <bound method NDFrame.head of       prefix                                         input_text  \
# 0     webNLG  Estádio_Municipal_Coaracy_da_Mata_Fonseca | lo...
# 1     webNLG  Estádio_Municipal_Coaracy_da_Mata_Fonseca | lo...
# 2     webNLG  Nie_Haisheng | birthDate | 1964-10-13 && Nie_H...
# 3     webNLG  Nie_Haisheng | birthDate | 1964-10-13 && Nie_H...
# 4     webNLG  Nie_Haisheng | birthDate | 1964-10-13 && Nie_H...
# ...      ...                                                ...
# 5145  webNLG  Turn_Me_On_(album) | genre | Punk_blues && Tur...
# 5146  webNLG  Turn_Me_On_(album) | genre | Punk_blues && Tur...
# 5147  webNLG  Ciudad_Ayala | country | Mexico && Ciudad_Ayal...
# 5148  webNLG  Ciudad_Ayala | country | Mexico && Ciudad_Ayal...
# 5149  webNLG  Ciudad_Ayala | country | Mexico && Ciudad_Ayal...
#
#                                             target_text
# 0     Estádio Municipal Coaracy da Mata Fonseca is t...
# 1     Estádio Municipal Coaracy da Mata Fonseca is t...
# 2     Nie Haisheng, born on October 13, 1964, worked...
# 3     Nie Haisheng is a former fighter pilot who was...
# 4     Nie Haisheng born on 10/13/1964 is a fighter p...
# ...                                                 ...
# 5145  The Honeymoon Killers is the producer of the p...
# 5146  The American Band, the Honeymoon Killers, self...
# 5147  Ciudad Ayala is in the country of Mexico and i...
# 5148  Ciudad Ayala is a Mexican city located in the ...
# 5149  Ciudad Ayala located in the country of Mexico ...
#
# [5150 rows x 3 columns]>

# %%
input_list = test_df['input_text'].tolist()
target_list = test_df['target_text'].tolist()

# %%
# let's get rid of duplicate triples
filtered_instances = []
for triples, targets in zip(input_list, target_list):
  #print(f"number of triples: {len(re.findall('&&', triples))}")
  #print(f"triples : {triples}")
  #print(f"targets : {targets}")
  triple_set = set()
  triples_list = triples.split("&&")
  #print(len(triples_list))
  for t in triples_list:
    t = t.strip()
    #print(t)
    triple_set.add(t)
  if len(triple_set) == 1:
    filtered_instances.append(tuple((triple_set, targets)))

# %%
# this cell is just for inspection
print(f"Number of 1 triple instances in the test set: {len(filtered_instances)}")
#for x, y in filtered_instances:
  #if len(x) == 1:
    #print(x)
    #print(len(x))
    #print(y)
# Out:
# Number of 1 triple instances in the test set: 736

# %%
# create a new dataframe and save it to the csv file
df_test_1triple = pd.DataFrame(filtered_instances, columns =['input_text', 'target_text'])
df_test_1triple.to_csv('/content/gdrive/My Drive/WebNLG with GPT2/data/webNLG2020_test_1triple.csv')

# %%
#let's load the saved file

#Lets check the file:
test1triple_df=pd.read_csv('/content/gdrive/My Drive/WebNLG with GPT2/data/webNLG2020_test_1triple.csv', index_col=[0])

# %%
def remove_unwanted_chars(text):
  remove_list = ["[", "]", ")", "(", "'", "{", "}", "<", ">"]
  for char in text:
    if char in remove_list:
      text = text.replace(char, "")
  return text

# %%
test1triple_list = test1triple_df['input_text'].tolist()
clean_list = []
for x in test1triple_list:
  x = remove_unwanted_chars(x)
  clean_list.append(x)

# %%
test1triple_df['input_text'] = clean_list

# %%
test1triple_df['input_text']
# Out:
# 0                          Darlington | areaCode | 01325
# 1                          Darlington | areaCode | 01325
# 2                          Darlington | areaCode | 01325
# 3              Israel | officialLanguage | Modern_Hebrew
# 4              Israel | officialLanguage | Modern_Hebrew
#                              ...
# 731    English_Without_Tears | writer | Anatole_de_Gr...
# 732    English_Without_Tears | writer | Anatole_de_Gr...
# 733                  Nurhan_Atasoy | birthPlace | Turkey
# 734                  Nurhan_Atasoy | birthPlace | Turkey
# 735                  Nurhan_Atasoy | birthPlace | Turkey
# Name: input_text, Length: 736, dtype: object

# %%
test1triple_df['target_text']
# Out:
# 0         The Darlington town has an area code of 01325.
# 1       The telephone area code for Darlington is 01325.
# 2                  The area code in Darlington is 01325.
# 3      The official language of Israel is modern Hebrew.
# 4           Israel’s official language is Modern Hebrew.
#                              ...
# 731    The writer of English Without Tears was Anatol...
# 732    "English Without Tears" was written by Anatole...
# 733                Nurhan Atasoy's birthplace is Turkey.
# 734    The place where Nurhan Atasoy was born is Turkey.
# 735                    Nurhan Atasoy was born in Turkey.
# Name: target_text, Length: 736, dtype: object

# %% [markdown]
# It is time to generate sentences:

# %%
#set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#load the trained model
model = GPT2LMHeadModel.from_pretrained("/content/gdrive/My Drive/WebNLG with GPT2/model")
model.to(device)
print(device)
# Out:
# cuda

# %%
#load the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-medium', bos_token='<|startoftext|>',
                                          eos_token='<|endoftext|>', pad_token='<|pad|>')
# Out:
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
#inference function

def gen_text(triple, tokenizer, model):
  """generate sentence"""
  prompt = tokenizer("<|startoftext|>Triple:{} Target".format(triple), return_tensors="pt").input_ids.cuda()
  outputs = model.generate(prompt, do_sample=True, top_k=2, max_length=70, top_p=0.95, temperature=1.9, num_return_sequences=1)
  # change num_return_sequence if you want to generete more than one sentence with the given input
  for i, sample_output in enumerate(outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    text = text.strip("<endoftext><startoftext>\n ")
    text = text.split("Target: ")
    text = text[-1]
    #text = text.split("Target: ")
    #text = text[1]
    #text = text.strip('<endoftext>')
  return str(text)

# %%
test_triple = "Fina | birthDate | 30 April"
test_output = gen_text(test_triple, tokenizer, model)

print(test_output)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The date of birth of the Fina is 30 April.

# %%
gen_text_list = []
for rdf in clean_list:
  text = gen_text(rdf, tokenizer, model)
  gen_text_list.append(text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
for text in gen_text_list:
  #text = text.strip("<endoftext><startoftext>\n ")
  #text = text.split("Target: ")
  #text = text[-1]
  print(text)
# Out:
# 01325 is the area code for Darlington, in England and Wales. The area codes for Darlington are 01326 and 01327. The area codes for the area codes of the area code of the area code is 01326 and 01327. The area codes of th
# 01325 is the area code of Darlington, in England, in England, in England. The area code of Darlington, is 01 325. The total area code for the city of Darlington, is 01325.
# The area codes for the area codes of Darlington are 01325 and 01325.
# Modern Hebrew is a native language of the Israelites. The language spoken in the country of Israel is spoken in the Modern Hebrew. The language spoken is spoken in the country of the Jews. The language spoken in the country of the Jews is Modern Hebrew.
# Modern Hebrew is a language of the Israeli people.
# Modern Hebrew is the official language in Israel.
# Chinabank is located within the Philippine city of Manila. The location of Chinabank in the Philippines is the city of Manila, Philippines.
# Chinabank are located in the Philippines.<startoftext>Triple: Manila,_Philippines is a city of the Philippines.
# The singer and musician, Darinka Dentcheva, was influenced by Andrzej Prutzczyński.
# The musical influences for Darinka Dentcheva are the music influenced by Andrzej Piotr Ruszczyński. The musical influences of Darinka Dentch
# The singer Andrzej Piotr Ruszczyński influenced Darinka Dentcheva.
# George Monson's wife is Mary Annonson.
# George Martin's spouse was Lady Anne Monson, who was married to George Monson in 18 1876. George Martin 1876 was the date on which the marriage was 1876. 1876 was th
# George Monson's wife is Mary Anne Monson. George M.onson was a married couple in the 1930's. Ms. Annonson was a married couple Ms. A
# Detroit has a total of 370.03 inhabitants.
# The total area of Detroit, Michigan is 370.03. The total area of Detroit is 370.03.
# Punk music has a drum kit in it. The drummer is a guitar player. The instrument is a guitar player. The instrument is the drummer's instrument. The instrument is the guitar's instrument."
# The official language in Israel is Modern Standard Arabic.
# Modern Standard Arabic is the official language of the Israel's official language.
# Universal music group owns the Triples record label.
# The Universal Music Group owns Triples Recordings.
# Universal Music Group is the parent company of Triple:Polydor Recordings.
# The writer for the Mermaid Train Song is Stargate Production team. The writer for the Mermaid Train Song was the production team of the film Stargate Production team.
# The writers of the Mermaid Train Song are the production team of the Stargate production team.
# Leni Robredo is the leader ofPhilippines.
# Leni Robredo is a leader of the Philippines.
# Leni Robredo is a member of the Philippine Nationalist Movement (PNM). Leni Robredo was a member of the Philippines Nationalists during its independence period.Philippine Nationalist Movement (PNM) is theedipalistedipovernm
# Leni Ribeiro is the Philippines leader in the Philippines.
# The United States is a citizen of Darinka Dentcheva's nationality."
# Darinka Dentcheva is an American citizen. The United States has the citizenship of Darinka Dentcheva. 2004".
# 16800 undergraduates is the university of Burgundy's number of undergraduates. The university has 16800 undergraduates. The number of undergraduates in the university of Burgundy is 17800. The university of Burgundy has 16
# The number of undergraduate students at the University of Burgundy is 16800.
# The University of Burgundy has 16,800 students. The university has a total of 16,800 undergraduate students.
# The University of Burgundy has 27400 students.
# University of Bruges has 27400 students. The university has 27400 students in total. The number of students in the university is 27400 students.
# The number of undergraduates at the University of Bruges is 27400.<startoftext>Triple:University_of_Burgundy | number of students is 27400.
# The record label for Mermaid Train Song is Sony Entertainment. The record label for Mermaid Train Song is Sony Entertainment. The record label for Mermaid Train is Sony Entertainment. The record label for Mermaid Train is Sony Entertainment. The record label for Mermai
# The record label for the Mermaid Train song is Sony Entertainment. The label of the record label is Sony Music Entertainment.
# Mermaid Train song was written and recorded by the Sony music entertainment label.
# The German Empire is a currency in Germany. The currency in Germany has a currency called the German Papiermark. The German Empire is a currency of the German Peninsula.
# The currency of Germany is the Germans Papiersmark.
# German Empire currency is the German Papiermark.
# Terence Rattigan was born on the 31st of January 1977, the date of the first death of his wife. He died on January 1st, 1978, on the date of theth anniversary of theth birthday of the fi
# The death of Terence Reid is in the year 1977-01-01.
# The Tolkien notable work is The Silmarillion, the title given to the work of J.R. Tolkien in the-1940s.
# J.R._R. Tolkien was notable for his work in the Silmarillion. The Silmarillion was the title of the 2000 edition of The Hobbit. The title of th
# J. R. Tolkien was notable for his works in the Silmarillion, which was published 1872.
# Ciudad Ayala is a city located within the city.
# The music of Noise rock was influenced from Noise music.
# The stylistic origin of Noise rock is Noise music. The stylistic origins of Noise rock are Noise music. The stylistic origins of Noise music are Noise music.
# Noise music is the stylistic origin for the Noise rock stylistic style.
# The nationality of Nie Hilaire Haisheng was Chinese.
# Nie Hilaire Haisheng was born in the Peoples Republic of China in Nie Hilaire Hausheng's nationality, Peoples Republic of China.
# The instrument used in the band Post Metal is the synthesizers.
# The instrument of Post metal is the Synthesizer, which is used in the recording of Post metal.
# The synthesizer is the instrument used to produce post-rock music.<startoftext>Triple: Post-rock music is a genre of music that has beenated.
# Bootleg series volume 1 The Quine tapes is a genre rock music record.
# The Chief Justice is the title of the leader in India. The Chief Justice is the title of Chief Justice in India. The Chief Justice is the title of the Chief Justice in the United States."
# Chief Justice is the title of Chief Justice of India.
# The UTC offset of San Francisco is minus 7. The UTC offset of San Francisco is minus 7.
#
#  December 2004
# The UTC offset of the San Francisco utcOffset is -7.
# San Jose has an offset of minus 7.
# Brandon was born in England in the year2032.
# Brandon Carter was born in England in the year2023.
# Nurhan Atasoy is an American citizen of Turkey.
# Turkish
# The citizenship of Nürhan Atasoy is Turkey. The citizenship of Nurhan Atasoy is Turkey.
# Nurhan Atasoy was a Turkish citizen born in Turkey.
# Turkish citizenship: Nurhan Atasoy was a Turkish citizen born in Turkey.
# Morelos has a total area of 4879.0 square kilometres.
# The total area of Morelos is 4879.0.
# Morelos has a total area of 4878.0 square kilometres. The total area of Morelos is 4879.0 square km."
#
#  December 2014
# Ciudad Ayala's office type is the council-manager government type. The government type of the Ciudad Ayala office is Council manager Government.
# The council manager government is the Government type of government.
# The council-manager government is the type of government in Ciudad Ayala, which was founded in11th century BC.
# The key person for Lionsgate is the Michael R. Burns. The character Michael Burns wased by Lionsgate in 2010. The 2010 film Lionsgate wased in millimetres of mercury.
# Michael Rivers is the key person for Lionsgate.
#
#  December 2004
# The key person for Lionsgate is Michael Burns. Michael R. Burns is the key player in Lionsgate's film Lions Gate.
# The Decemb
# The utc offset is the offset of the Ciudad Ayala in UTC. The utc offset is -6".
# The utc offset of the Ciudad Ayala is -6. The utc offset is −6 in the decimal place. The utcOffset of Ciudad Ayala are -6. The decimal place of the Ciudad Ay
# Ciudad Ayala's UTC offset is −6.0 (kilometres).
# Turkey has an area of water of 1.3 per square kilometre. Turkey has a percentage of area water in the sea area. Turkey has an area of water inches per square km. Turkey has a percentage of area of water inches in the sea area.
# Turkey has a percentage of water in the ground level at sea level of 0.3 meters. Turkey has a total of 1.3 water in the ground level. Turkey has a percentage of water in the ground level at sea level of 1.3 metres. Turkey h
# Turkey has a percentage area water of 1.3%.
# Istanbul has an offset of 2. The utc offset of Istanbul is +2.
# The UTCOffset of Istanbul is 2.
# Polydor Records is distributed by Interscope GEffen A&M. The labels of Polydor Records are Interscope Geffen A&M. The label of Interscope Geffen A&
# The label for Polydor Records is interscope Geffen A&M. The label for Polydor Records is Interscope Geffen A&M. The label of Polydor Records is Intersc
# Ray Giggs is a director of the Super Capers. Thecapers October 2014. The writer of the Super Capers is Ray Griggs. October 2014.
# Ray Griggs was the author of the comic book Super Caper. Thecapers 2011 is the 2011 date of the comic book Super Caper. 2011 is the date of the comic book
# Ray Gigicovsky was the writer for the Super Capers. Theth writer was Ray Gigicovsky.th year was 1941. The author of the SuperCaps was the writer for the Super Capers.
# Alan Jaggs is an editor at English Without Tear. Alan Jaggs 2004 is Alan Jaggs's editing title.
# The editing process of English Without Tears is Alan Jaggs's. December 2004. Alan Jaggs was editing th
# The English without tears is edited by Alan Jaggs. Alan Jaggs 2008.
# The birthplace of Nie Härtel is Zaoyang, theth century AD. Theth century AD was theth century AD, and Nie Härtel was the centenary year of the centennial of the c
# The assembly line 1986 was the date of the first 1986 Pontiac Rageous."
# The Pontiac Rage is assembled in the city of Detroit.
# The University of Burgundy is located within the French province of Burgundy. French is a number in France. The University of Burgundy has a total of million inhabitants in the French Province of Burgundy, France. The university of Burgundy h
# University of Burgundy is located in the French country, and is considered a member of the French National Assembly."
# The record label for the Mermaid Train song is Columbia Records. The label for the Mermaid Train song is Columbia Recordings. The label for the record called the Mermaid Train is Columbia Records.
# The record label of the millimetres of the millimetre of the Mermaid train song is Columbia Record.
# Columbia Records is the record label for the Mermaid Train song, "Mermaid Train". The label is Columbia Records. The record label for "Mermaid Train" is Columbia Records. The record label for "Mary Elizabeth" is Columbia Rec
# Grigory Neujmin was born on January 31, 1887, on the date of "1887". The date of birth is 1886-01-01.
# Th
# The date of Grigory Neujmin's birth is 1886-01-01.
# The music downloaded is a musical download of the music in the millimetres. The format of music downloads is the music downloaded format of millimetres. The music download 1996 is the music download format of millim
# The musical download is a song called "Mermaid Train song". The format of music download is music download format. 20th March 2011".
# The music download is a music download format used in the millimetre millimetres of the millimetres of the song. The format of the music downloads is: The music download is a musical download. The music downloads format is: Music download.
# Harry Carey was born 1878.
# Harry Carey starred 1878 as the writer of McVeagh of the South Seas. Harry Carey starred 1878 in the screenplay of McVeagh of the Seas. Harry Carey
# The writer of the novel McVeagh of the South Seas is Harry Carey actor born1878. The book McVeagh of the South Seas is written by Harry Carey actor born 1878
# Triple:Imagine_John_Lennon_song | album | Imagine_John_Lennon_album Target:Imagine John Lennon sings the Imagine John Lennon album.
# Imagine John Lennon sings Imagine John Lennons album. The record is called "Imagine John Lennons" and the album is called "The Beatles". 2011"
# The Honeymoon Killers American band is the name of the record Turn Me on. The name of the band is the honeymoon killer. The title of the record Turn Me on is The Honeymoon Kill
# The Honeymoon Killers American band was produced by The Honeymoon Killers. The Honeymoon Killers American band was written and performed by the Honeymoon Killers. The Honeymoon Killers American band w
# The Honeymoon Killers American band was created by the Honeymoon Killers. The song "Turn Me On" is a song by The Honeymoon Killers American band.
# The online gamingmanga is a product of GMA New Media. Themanga is a product of GMA New Media.manga is an online game. The product of the GMA New Media are the online game. GMA
# The online gamingmanga is the online game of the gma New Media company.<startoftext>Triple: GMA New Media | isPartOf The New Media Company.
# The Online Game is the product of GMA New Media. The number ofth October October 2016 was 2016 was the digital editi
# The Online Game is the product of GMA New Media. The Online Game includes 1996.
# Pop music is a genre of pop rock music. Pop music is an alternative genre to indie pop music. Indie pop music has a similarody of genre to pop music. October 2016".
# Pop rock is an indie pop music genre, with a heavyerb-poping genre. Pop rock has a heavy aerb pop and a heavier aerb-pop than Indie pop music. October 2014.
# The band Nord Year of No Light has their roots in Sludge metal. The band is called Nord Year of Light.
# Nords Year of Light is a Sludge metal album.
# Nords Year of Light is a Sludge Metal album.
# The band "Train Band" is based in Pop Rock. The genre of the music genre is pop rock.
# The musical genre of the band Train is Pop rock.
# Pop
# The distributor of the trilogy McVeagh of the South Seas is Alliance Films Corporation.
# The distributor of the trilogy, McVeagh, of the South Seas, is Alliance Films Corporation.
# The time zone for Ciudad Ayala is Pacific Daylight Time (PST).
# Ciudad Ayala is in the time zone of Pacific Daylight Time.
# The parent company of the Pontiac is the general Motors company.
# The company of Pontiac is General Motors. General Motors is the parent company of Pontiac. General Motors parent company of General Motors is the company of Pontiac. General Motors is the parent company of General Motors. General Motors was the parent company of Pontiac.
# The parent company of the Pontiac is General Motors. The parent company is General Motors.
# The Bootleg Series Volume 1: The Rox Tape was released on the 16th of October 2001. The release date for The Rox Tape is 2001-10-16. The Bootleg Seri
# The Bootleg series volume 1 The Quine tapes were published on 10-16-2001. The date on the release date is the date of the DVD/BluRay release date. Th
# Bootlegged volumes 1 and 2 were released on 10-16th October 2001. The bootlegged volumes 1 and 2 were released on the 16th October 2001.
# The utcOffset is 8 inches from the UTC zone.
# The utcOffset of Zaoyang is -8.
# The utcOffset of Zaoyang is -8.0.
# Max Bertram began his career on January 1st 1947. Max Bertram started his career on January 1st, 1947.
#
# 1947: Max Bertram began his career on January 1st, 1947
# The year in Max Benedict's career was January 01, 1947. Max Benedicts was active on January 01, 1947.
# Max Benedict started his career in 1947-01-01. He started his career on January 1st 1947.
# Mary Hayes Bell is the wife of the John Mills family. Mary Hayes was married to John Mills in 18 1872.Mary was born in 1873 and died in 1873. John Mills was born in 18 1972."
# John Mills was a married couple. Mary Hayes Bell was the spouse of John Mills.
# John Mills is married to Mary Hayley Bell.
#
# <startoftext>Triple: John Mills | spouse | Mary Hayley Bell, is the wife of John Mills.
# The birthplace of Justin Whitman was San Francisco.
# Justin Whitman was born in San Francisco, California.
# The leader of Morelos is Governor.
# The leader title of Morelos is Governor.
# Governor of Morelos is the name of the politician in office of the Governor of the city of Morelos.
# David Sainsbury, Baron Sainsbury of Cambridge was chancellor at the University of Cambridgeshire.
# The chancellor at University of Cambridge is David Sainsbury of Torville.
# The Chancellor of University Cambridge is David Sainsbury, Baron Sainsbury of Turville. The chancellor of the University of Cambridge is David Sainsbury, Baron Sainsbury
# The two towers of the trilogy are J.R. Tolkien's The Two Towers and J.R.R. Tolkien's The Two Towers. The author of the 1976 novel The Two Towers is J.R. Tolkien.
# The two Towers were written by the author of The Hobbit: an epic novel. Tolkiened his 1976.
# The author of The Two Towers is J.R. Tolkien.
# The residence of Nurhan Atasoy was Teşvikiye.
# Nurhan Atasoy lives at Teşvikiye in Turkey."
# Nurhan Atasoy's residence is teşvikiye.
# The number of undergraduate students at the University of Burgundy is 1299.
# The University of Burgundy has 1299 students. The university of Burgundy is located at 1299 university square kilometres in Burgundy, France. The number of Doctoral students in the university of Burgundy is 1299.
# Justin Whitman is a Presenter at the University of California at Berkeley.
# Justin Whitman is the Presenter at the university of Illinois at Urbana-Champaign.
# The singer/songwriter is a Presenter of the band, Justin Whitman.
# The birth place of Cyril Francois was the United Kingdom."
# Cyril Frankel was born in the United Kingdom.<startoftext>Triple:Cyril_Frankel | country | United_Kingdom.
# Cyril Francois was born in the United Kingdom.
# The birth place of Harold French was the UK.
# The birth place of Harold French is the UK."
# The October 2008 was the date of death of Harold French.
# Nie Haisheng's birth date was 1963. The date of birth of Nie Haisheng is 1964-10-13. The date of birth of the Nie Haisheng family is 1964-10-13.
# The date of birth of Nie Haisheng was on the 13th of October 1964.
# Nie Hausheng's birth date is 1964-10-13.
# Anatolins de Grunwald was born in Saint Petersburg, Saint Petersburg, the birthplace of Anatolins de Grunwald. The birthplace of Anatolin de Grunwald is St Petersburg
# The birthplace is Saint Petersburg in Saint Petersburg, Russia.
# The birthplace of Anatole de Groswald is Saint Petersburg, in Saint Petersburg, Russia.
# Hobbits are known for their literary genre of High fantasy. The literary genre of the Hobbits is the High Fantasy. October 2011 is theth anniversary of the publication of the book The Hobbit by th
# The Hobbit is a literary genre of the Hobbits.
# Cuernavaca is part of Morelos.com.
# Cuernavaca is a part of the city in Morelos, Mexico.
# University of Cambridge is a research university in the United States.
# The absolute magnitudes of 1147 Stavropolis are 11.5. The absolute magnitudes of 1147 Stavropol is 11.5.
# 1147 St. Avon St. has an absolute magnitude of 11.5 (in degrees Celsius). The absoluteMagnitude of 11.5 is 11.5. The absoluteMagnitude of 1147 is 11.5. The absolute magnitu
# 1147 St. Petersburg is 11.5 degrees above the absolute magnitude of 1146 St. Petersburg in the absolute magnitude of 1146 St. Petersburg in the total magnitude of 1146 St. Petersburg in the total area.
# John Mills stars as John Mills in the 1957 film "Its Great To Be Young 1957."
# John Mills starred in the 1957 movie "Its Great to be Young 1955." The film starred John Mill as the character "John Mills." Trivia: 1956" w
# The film starring John Mills was made in 1957. The character of its Great to be Young 1955 film is called John Mills.<startoftext>Triple: The Great to Be Young 1955 film was starring Joh
# The writer Anatole de Grover was a writer for English without tears.
# The writer of English Without Tears is Anatolian De Grosberg.
# Anatolian De Grunwald was the author of the novel English without tears, which was 2004.
# The birthplace of Nurhan Asoy is Turkey."
# The birthplace of Nurhan Atasoy was Ankara, Turkey. The birth place of Nurhan Atasoy is Ankara, Turkey.
# The birthplace of Nurhan Atasoy is Ankara.

# %%
test1triple_df['generated_text'] = gen_text_list

# %%
test1triple_df['generated_text']
# Out:
# 0      01325 is the area code for Darlington, in Engl...
# 1      01325 is the area code of Darlington, in Engla...
# 2      The area codes for the area codes of Darlingto...
# 3      Modern Hebrew is a native language of the Isra...
# 4      Modern Hebrew is a language of the Israeli peo...
#                              ...
# 731    The writer of English Without Tears is Anatoli...
# 732    Anatolian De Grunwald was the author of the no...
# 733            The birthplace of Nurhan Asoy is Turkey."
# 734    The birthplace of Nurhan Atasoy was Ankara, Tu...
# 735           The birthplace of Nurhan Atasoy is Ankara.
# Name: generated_text, Length: 736, dtype: object

# %%
test1triple_df.head
# Out:
# <bound method NDFrame.head of                                             input_text  \
# 0                        Darlington | areaCode | 01325
# 1                        Darlington | areaCode | 01325
# 2                        Darlington | areaCode | 01325
# 3            Israel | officialLanguage | Modern_Hebrew
# 4            Israel | officialLanguage | Modern_Hebrew
# ..                                                 ...
# 731  English_Without_Tears | writer | Anatole_de_Gr...
# 732  English_Without_Tears | writer | Anatole_de_Gr...
# 733                Nurhan_Atasoy | birthPlace | Turkey
# 734                Nurhan_Atasoy | birthPlace | Turkey
# 735                Nurhan_Atasoy | birthPlace | Turkey
#
#                                            target_text  \
# 0       The Darlington town has an area code of 01325.
# 1     The telephone area code for Darlington is 01325.
# 2                The area code in Darlington is 01325.
# 3    The official language of Israel is modern Hebrew.
# 4         Israel’s official language is Modern Hebrew.
# ..                                                 ...
# 731  The writer of English Without Tears was Anatol...
# 732  "English Without Tears" was written by Anatole...
# 733              Nurhan Atasoy's birthplace is Turkey.
# 734  The place where Nurhan Atasoy was born is Turkey.
# 735                  Nurhan Atasoy was born in Turkey.
#
#                                         generated_text
# 0    01325 is the area code for Darlington, in Engl...
# 1    01325 is the area code of Darlington, in Engla...
# 2    The area codes for the area codes of Darlingto...
# 3    Modern Hebrew is a native language of the Isra...
# 4    Modern Hebrew is a language of the Israeli peo...
# ..                                                 ...
# 731  The writer of English Without Tears is Anatoli...
# 732  Anatolian De Grunwald was the author of the no...
# 733          The birthplace of Nurhan Asoy is Turkey."
# 734  The birthplace of Nurhan Atasoy was Ankara, Tu...
# 735         The birthplace of Nurhan Atasoy is Ankara.
#
# [736 rows x 3 columns]>

# %%
test1triple_df.to_csv('/content/gdrive/My Drive/WebNLG with GPT2/data/output/webNLG2020_test_with_generated_outputs.csv')

# %%
# Let's check how the file looks:
gen_df=pd.read_csv('/content/gdrive/My Drive/WebNLG with GPT2/data/output/webNLG2020_test_with_generated_outputs.csv', index_col=[0])
gen_df.head
# Out:
# <bound method NDFrame.head of                                             input_text  \
# 0                        Darlington | areaCode | 01325
# 1                        Darlington | areaCode | 01325
# 2                        Darlington | areaCode | 01325
# 3            Israel | officialLanguage | Modern_Hebrew
# 4            Israel | officialLanguage | Modern_Hebrew
# ..                                                 ...
# 731  English_Without_Tears | writer | Anatole_de_Gr...
# 732  English_Without_Tears | writer | Anatole_de_Gr...
# 733                Nurhan_Atasoy | birthPlace | Turkey
# 734                Nurhan_Atasoy | birthPlace | Turkey
# 735                Nurhan_Atasoy | birthPlace | Turkey
#
#                                            target_text  \
# 0       The Darlington town has an area code of 01325.
# 1     The telephone area code for Darlington is 01325.
# 2                The area code in Darlington is 01325.
# 3    The official language of Israel is modern Hebrew.
# 4         Israel’s official language is Modern Hebrew.
# ..                                                 ...
# 731  The writer of English Without Tears was Anatol...
# 732  "English Without Tears" was written by Anatole...
# 733              Nurhan Atasoy's birthplace is Turkey.
# 734  The place where Nurhan Atasoy was born is Turkey.
# 735                  Nurhan Atasoy was born in Turkey.
#
#                                         generated_text
# 0    01325 is the area code for Darlington, in Engl...
# 1    01325 is the area code of Darlington, in Engla...
# 2    The area codes for the area codes of Darlingto...
# 3    Modern Hebrew is a native language of the Isra...
# 4    Modern Hebrew is a language of the Israeli peo...
# ..                                                 ...
# 731  The writer of English Without Tears is Anatoli...
# 732  Anatolian De Grunwald was the author of the no...
# 733          The birthplace of Nurhan Asoy is Turkey."
# 734  The birthplace of Nurhan Atasoy was Ankara, Tu...
# 735         The birthplace of Nurhan Atasoy is Ankara.
#
# [736 rows x 3 columns]>

# %% [markdown]
# End of the notebook.
